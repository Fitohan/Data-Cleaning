# %% [markdown]
# Question
# Your task for the week is to clean this dataset. Using your notebook, ensure that the steps taken are clear and concise,
# with proper commenting.Additionally, you'd write a report stating in detail, the steps you took, and the reason why.

# %%
import pandas as pd    #data preprocessing
import numpy as np     #numerical operations

# %%
#To import the data set 

dataset = pd.read_csv (r"C:\Users\FITOHAN\Desktop\Python training\hepatitis file.csv")

# %%
#Check if the data set imported successful

dataset.head()
# Out:
#    age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0   30    male   False       False   False   False    False     False
# 1   50  female   False       False    True   False    False     False
# 2   78  female    True       False    True   False    False      True
# 3   31  female     NaN        True   False   False    False      True
# 4   34  female    True       False   False   False    False      True
#
#   liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0      False           False   False   False   False        1.0
# 1      False           False   False   False   False        0.9
# 2      False           False   False   False   False        0.7
# 3      False           False   False   False   False        0.7
# 4      False           False   False   False   False        1.0
#
#    alk_phosphate   sgot  albumin  protime  histology class
# 0           85.0   18.0      4.0      NaN      False  live
# ...

# %%
#check the shapes to know how the numbers of rows and columns in the dataset(number of rows, number of columns).
dataset.shape
# Out:
# (155, 20)

# %%
#check the statisticalinformation
dataset.describe()
# Out:
#               age   bilirubin  alk_phosphate       sgot     albumin  \
# count  155.000000  149.000000     126.000000  151.00000  139.000000
# mean    41.200000    1.427517     105.325397   85.89404    3.817266
# std     12.565878    1.212149      51.508109   89.65089    0.651523
# min      7.000000    0.300000      26.000000   14.00000    2.100000
# 25%     32.000000    0.700000      74.250000   31.50000    3.400000
# 50%     39.000000    1.000000      85.000000   58.00000    4.000000
# 75%     50.000000    1.500000     132.250000  100.50000    4.200000
# max     78.000000    8.000000     295.000000  648.00000    6.400000
#
#           protime
# count   88.000000
# mean    61.852273
# std     22.875244
# min      0.000000
# 25%     46.000000
# 50%     61.000000
# 75%     76.250000
# max    100.000000

# %%
#check the general information this also includes the datatypes
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              155 non-null    int64
#  1   sex              155 non-null    object
#  2   steroid          154 non-null    object
#  3   antivirals       155 non-null    bool
#  4   fatigue          154 non-null    object
#  5   malaise          154 non-null    object
#  6   anorexia         154 non-null    object
#  7   liver_big        145 non-null    object
#  8   liver_firm       144 non-null    object
#  9   spleen_palpable  150 non-null    object
#  10  spiders          150 non-null    object
#  11  ascites          150 non-null    object
#  12  varices          150 non-null    object
#  13  bilirubin        149 non-null    float64
#  14  alk_phosphate    126 non-null    float64
#  15  sgot             151 non-null    float64
# ...

# %%
#make a copy reason is because if you need to make a reference back to the original dataset 
#or if you have make a mistake while working on the dataset
dataset1 = dataset.copy()

# %%
#This shows the columns with missing values or Nan 
dataset.isnull().sum()
# Out:
# age                 0
# sex                 0
# steroid             1
# antivirals          0
# fatigue             1
# malaise             1
# anorexia            1
# liver_big          10
# liver_firm         11
# spleen_palpable     5
# spiders             5
# ascites             5
# varices             5
# bilirubin           6
# alk_phosphate      29
# sgot                4
# albumin            16
# protime            67
# histology           0
# class               0
# dtype: int64

# %%
#To fill in missing , "inplace=True in the DataFrame.backfill() method", 
#it will fill the missing values of the DataFrame but do not create a new object.

dataset.fillna(method="bfill",inplace = True)
print(dataset_fill) 
dataset
# Out:
# None
#      age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    male    False       False    False    False     False      False
# 1     50  female    False       False     True    False     False      False
# 2     78  female     True       False     True    False     False       True
# 3     31  female     True        True    False    False     False       True
# 4     34  female     True       False    False    False     False       True
# ..   ...     ...      ...         ...      ...      ...       ...        ...
# 150   46  female     True       False     True     True      True       True
# 151   44  female     True       False     True    False     False       True
# 152   61  female    False       False     True     True     False      False
# 153   53    male    False       False     True    False     False       True
# 154   43  female     True       False     True    False     False       True
#
# ...

# %%
dataset.isnull().sum()
# Out:
# age                0
# sex                0
# steroid            0
# antivirals         0
# fatigue            0
# malaise            0
# anorexia           0
# liver_big          0
# liver_firm         0
# spleen_palpable    0
# spiders            0
# ascites            0
# varices            0
# bilirubin          0
# alk_phosphate      0
# sgot               0
# albumin            0
# protime            0
# histology          0
# class              0
# dtype: int64

# %%
#checking the datatypes after filling the missing values,
#I observed that some of the datatype changed that contained Nan(missing values) from object to bool
#(to the orignal datatype of the column).
dataset.dtypes
# Out:
# age                  int64
# sex                 object
# steroid               bool
# antivirals            bool
# fatigue               bool
# malaise               bool
# anorexia              bool
# liver_big             bool
# liver_firm            bool
# spleen_palpable       bool
# spiders               bool
# ascites               bool
# varices               bool
# bilirubin          float64
# alk_phosphate      float64
# sgot               float64
# albumin            float64
# protime            float64
# histology             bool
# class               object
# dtype: object

# %%
#Rename a column's header, reason because spider is an insect name to familiar symptoms of hepatitis
hepatitis_1=dataset.rename(columns = {"spiders" : "jaundice"})
hepatitis_1
# Out:
#      age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    male    False       False    False    False     False      False
# 1     50  female    False       False     True    False     False      False
# 2     78  female     True       False     True    False     False       True
# 3     31  female     True        True    False    False     False       True
# 4     34  female     True       False    False    False     False       True
# ..   ...     ...      ...         ...      ...      ...       ...        ...
# 150   46  female     True       False     True     True      True       True
# 151   44  female     True       False     True    False     False       True
# 152   61  female    False       False     True     True     False      False
# 153   53    male    False       False     True    False     False       True
# 154   43  female     True       False     True    False     False       True
#
# ...

# %% [markdown]
# Report:
# Handle missing data:
# I handled the missing data by filling it up as a result to improve the quality and integrity of the data and as well for decison making; dropping or deleting missing value might lead to lost of information and integrity of the data which might be useful in future to make references well this is also dependent on how you want your analysis to be.
# To fill missing values or Nan in your data with the nearest value (not-Nan) in the future , backfilling is used but if you want to fill this NaN with the most recent not-NaN in the past,fowardfilling is used
# I used backfilling method because of further or future references.
#
# Change of name:
# I changed the column name "spiders" to "jaundice", because spider is a  class of insect. To layman who is not in the medical line wont be able to understand that spider is one of the symptoms of hepatitis, So inorder to make it meaningful amd understadable I change the name spider to jaundice.
